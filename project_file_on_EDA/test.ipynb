# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/user/veghar/project_datasets/global_climate_energy_2020_2024.csv')

# %%
df.head()
# Out:
#          date  country  avg_temperature  humidity  co2_emission  \
# 0  2020-01-01  Germany            28.29     31.08        212.63
# 1  2020-01-02  Germany            28.38     37.94        606.05
# 2  2020-01-03  Germany            28.74     57.67        268.72
# 3  2020-01-04  Germany            26.66     51.34        167.32
# 4  2020-01-05  Germany            26.81     65.38        393.89
#
#    energy_consumption  renewable_share  urban_population  \
# 0            11348.75            14.42             76.39
# 1             4166.64             5.63             86.26
# 2             4503.80            14.20             75.92
# 3             3259.13            13.84             63.15
# 4             7023.72             6.93             76.02
#
#    industrial_activity_index  energy_price
# 0                      51.22         83.93
# 1                      78.27        110.40
# 2                      48.96        173.58
# 3                      97.42         89.13
# ...

# %%
df.shape
# Out:
# (36540, 10)

# %%
df.isna().sum()
# Out:
# date                         0
# country                      0
# avg_temperature              0
# humidity                     0
# co2_emission                 0
# energy_consumption           0
# renewable_share              0
# urban_population             0
# industrial_activity_index    0
# energy_price                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['date', 'country', 'avg_temperature', 'humidity', 'co2_emission',
#        'energy_consumption', 'renewable_share', 'urban_population',
#        'industrial_activity_index', 'energy_price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36540 entries, 0 to 36539
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       36540 non-null  object
#  1   country                    36540 non-null  object
#  2   avg_temperature            36540 non-null  float64
#  3   humidity                   36540 non-null  float64
#  4   co2_emission               36540 non-null  float64
#  5   energy_consumption         36540 non-null  float64
#  6   renewable_share            36540 non-null  float64
#  7   urban_population           36540 non-null  float64
#  8   industrial_activity_index  36540 non-null  float64
#  9   energy_price               36540 non-null  float64
# dtypes: float64(8), object(2)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#        avg_temperature      humidity  co2_emission  energy_consumption  \
# count     36540.000000  36540.000000  36540.000000        36540.000000
# mean         13.580868     59.971469    445.820452         7295.904857
# std          10.077249     17.303103    234.360906         3693.928504
# min          -9.600000     30.000000     50.150000         1001.890000
# 25%           5.630000     45.010000    248.675000         4184.177500
# 50%          13.790000     59.990000    422.655000         6921.620000
# 75%          20.840000     74.970000    628.422500        10175.110000
# max          38.710000     90.000000    999.850000        15998.050000
#
#        renewable_share  urban_population  industrial_activity_index  \
# count     36540.000000      36540.000000               36540.000000
# mean         15.944080         74.982156                  70.173094
# std           5.334804          8.645400                  17.334816
# ...

# %%
df['country'].nunique()
# Out:
# 20

# %%
df['country'].value_counts()
# Out:
# country
# Germany           1827
# France            1827
# Mexico            1827
# South Africa      1827
# Australia         1827
# Japan             1827
# China             1827
# India             1827
# Brazil            1827
# Canada            1827
# United States     1827
# United Kingdom    1827
# Turkey            1827
# Poland            1827
# Norway            1827
# Sweden            1827
# Spain             1827
# Italy             1827
# Netherlands       1827
# Indonesia         1827
# Name: count, dtype: int64

# %%
df['avg_temperature'].mean().round()
# Out:
# 14.0

# %%
df['avg_temperature'].max()
# Out:
# 38.71

# %%
df.head()
# Out:
#          date  country  avg_temperature  humidity  co2_emission  \
# 0  2020-01-01  Germany            28.29     31.08        212.63
# 1  2020-01-02  Germany            28.38     37.94        606.05
# 2  2020-01-03  Germany            28.74     57.67        268.72
# 3  2020-01-04  Germany            26.66     51.34        167.32
# 4  2020-01-05  Germany            26.81     65.38        393.89
#
#    energy_consumption  renewable_share  urban_population  \
# 0            11348.75            14.42             76.39
# 1             4166.64             5.63             86.26
# 2             4503.80            14.20             75.92
# 3             3259.13            13.84             63.15
# 4             7023.72             6.93             76.02
#
#    industrial_activity_index  energy_price
# 0                      51.22         83.93
# 1                      78.27        110.40
# 2                      48.96        173.58
# 3                      97.42         89.13
# ...

# %%
df.loc[df['co2_emission'].idxmax()]['country']
# Out:
# 'Brazil'

# %%
df.groupby('country')['co2_emission'].max().reset_index()
# Out:
#            country  co2_emission
# 0        Australia        995.94
# 1           Brazil        999.85
# 2           Canada        998.16
# 3            China        998.94
# 4           France        990.57
# 5          Germany        995.41
# 6            India        997.98
# 7        Indonesia        999.30
# 8            Italy        997.72
# 9            Japan        998.41
# 10          Mexico        999.68
# 11     Netherlands        998.25
# 12          Norway        998.08
# 13          Poland        997.16
# 14    South Africa        983.97
# 15           Spain        999.48
# 16          Sweden        998.70
# 17          Turkey        996.26
# 18  United Kingdom        996.87
# 19   United States        998.51

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df,x='country',y='co2_emission',palette='viridis')
plt.xticks(rotation=90)
plt.title('CO2 Emission by Country')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_183/2176120093.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x='country',y='co2_emission',palette='viridis')

# %%
df.head()
# Out:
#          date  country  avg_temperature  humidity  co2_emission  \
# 0  2020-01-01  Germany            28.29     31.08        212.63
# 1  2020-01-02  Germany            28.38     37.94        606.05
# 2  2020-01-03  Germany            28.74     57.67        268.72
# 3  2020-01-04  Germany            26.66     51.34        167.32
# 4  2020-01-05  Germany            26.81     65.38        393.89
#
#    energy_consumption  renewable_share  urban_population  \
# 0            11348.75            14.42             76.39
# 1             4166.64             5.63             86.26
# 2             4503.80            14.20             75.92
# 3             3259.13            13.84             63.15
# 4             7023.72             6.93             76.02
#
#    industrial_activity_index  energy_price
# 0                      51.22         83.93
# 1                      78.27        110.40
# 2                      48.96        173.58
# 3                      97.42         89.13
# ...

# %%
df.tail()
# Out:
#              date    country  avg_temperature  humidity  co2_emission  \
# 36535  2024-12-27  Indonesia            10.91     85.88        134.23
# 36536  2024-12-28  Indonesia            10.91     65.14        366.68
# 36537  2024-12-29  Indonesia            10.91     66.33        256.12
# 36538  2024-12-30  Indonesia            10.91     39.18        251.60
# 36539  2024-12-31  Indonesia            10.91     54.24        444.88
#
#        energy_consumption  renewable_share  urban_population  \
# 36535             6607.39            22.04             69.43
# 36536             4654.41            23.79             62.66
# 36537             1982.89            14.92             77.53
# 36538             2689.54            21.66             62.92
# 36539             6227.33            22.28             73.13
#
#        industrial_activity_index  energy_price
# 36535                      76.38        160.33
# 36536                      43.33         58.49
# ...

# %%
df.loc[df['country'].idxmax()][['energy_price','country']]
# Out:
# energy_price            89.74
# country         United States
# Name: 18270, dtype: object

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=df,x='country',y='energy_price',palette='Set2')
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# /tmp/ipykernel_183/1999808664.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x='country',y='energy_price',palette='Set2')

# %%
df.sample(5)
# Out:
#              date         country  avg_temperature  humidity  co2_emission  \
# 28712  2023-07-31           Japan            18.63     89.90        113.85
# 33067  2020-06-30          Mexico            16.59     40.66        436.52
# 2159   2020-11-28          France             3.70     67.07        198.04
# 17494  2022-11-17  United Kingdom             2.83     51.56        338.48
# 305    2020-11-01         Germany            18.01     58.51        652.63
#
#        energy_consumption  renewable_share  urban_population  \
# 28712            10363.35            22.71             61.91
# 33067             7916.42             6.70             75.93
# 2159             10635.33             9.66             85.08
# 17494             8943.37            18.34             87.38
# 305               2939.11            13.27             86.63
#
#        industrial_activity_index  energy_price
# 28712                      54.63         77.48
# 33067                      58.99         51.21
# ...

# %%
df.groupby('country')['renewable_share'].max().reset_index().head()
# Out:
#      country  renewable_share
# 0  Australia            29.90
# 1     Brazil            30.13
# 2     Canada            30.75
# 3      China            30.12
# 4     France            30.87

# %%
df.sample(5)
# Out:
#              date       country  avg_temperature  humidity  co2_emission  \
# 8421   2023-01-18         Spain            20.23     41.34        346.67
# 6683   2023-04-17         Italy            33.18     72.90        148.04
# 32009  2022-08-08  South Africa            -1.87     78.71        750.14
# 34807  2020-04-04     Indonesia            18.61     38.61        181.42
# 23288  2023-09-26        Brazil            -4.42     67.94        760.93
#
#        energy_consumption  renewable_share  urban_population  \
# 8421              8568.50            20.75             89.74
# 6683             13926.76            15.25             64.40
# 32009             9566.77            19.45             88.36
# 34807            11049.13             7.51             67.91
# 23288            12812.43            25.26             66.45
#
#        industrial_activity_index  energy_price
# 8421                       92.45        197.29
# 6683                       68.73        165.66
# ...

# %%
sns.barplot(data=df,x='country',y='urban_population',hue='energy_price',palette='magma')
plt.xticks(rotation=90)
plt.title('country with urban population',color='red')
plt.tight_layout()
# Out:
# /tmp/ipykernel_183/692319507.py:4: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /nix/store/l9hjmd7yz977b9pah7h3dr727vb7f0mg-python3-3.11.10-env/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /nix/store/l9hjmd7yz977b9pah7h3dr727vb7f0mg-python3-3.11.10-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
